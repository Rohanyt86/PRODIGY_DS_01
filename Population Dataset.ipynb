# %% [markdown]
# ## Name:- Rohan Suvarna
#
# ## Domain:- Data Science
#
# ## Prodigy Infotech intern
#
# ## Task  2 :- Population Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
## load dataset

df = pd.read_csv(r"C:\Users\ROHAN SUVARNA\OneDrive\Documents\Rohan Suvarna\Projects\Data science\API_SP.POP.TOTL_DS2_en_csv_v2_5695140.csv")
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
## head
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
## tail
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5542459.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16520441.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3119430.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0  ...
# 262   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0  ...
# 263  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0  ...
# 264   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0  ...
# 265   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0  ...
#
#            2013        2014        2015        2016        2017        2018  \
# ...

# %%
## database

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
## seeing any null value and sum it

df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2018              1
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# Length: 67, dtype: int64

# %%
## clear null values 

df.dropna().isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# Length: 67, dtype: int64

# %% [markdown]
# ### Exploaratory data Analysis

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172707e+08  1.188803e+08  1.210506e+08  1.237328e+08  1.264374e+08
# std    3.695437e+08  3.740896e+08  3.808059e+08  3.895038e+08  3.982438e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291808e+08  1.320399e+08  1.348975e+08  1.378354e+08  1.408784e+08
# ...

# %%
grouped_data = df.groupby("Country Name")["1960"].sum()
top_categories = grouped_data.nlargest(5)

# Print the grouped data
print("Grouped Data:")
print(top_categories)
# Out:
# Grouped Data:
# Country Name
# World                  3.031474e+09
# IDA & IBRD total       2.297972e+09
# Low & middle income    2.243179e+09
# Middle income          2.107416e+09
# IBRD only              1.904347e+09
# Name: 1960, dtype: float64

# %%
plt.figure(figsize=(16,10))
plt.bar(top_categories.index,top_categories.values)
plt.xlabel("Country name")
plt.title("Highest population top 5")
plt.show()

# %% [markdown]
# - from above graphs we can say top 5 population country in year 1960.

# %% [markdown]
# ## Visualization

# %%
# Select the top 5 countries based on the population in 1970
top_countries_1970 = df.nlargest(5, '1970')

# Melt the DataFrame to reshape it for visualization
melted_df = top_countries_1970.melt(id_vars=['Country Name'], value_vars=['1960', '1970'], var_name='Year', value_name='Population')

# Create a vertical bar graph
plt.figure(figsize=(10, 6))
plt.bar(melted_df['Country Name'], melted_df['Population'], color=melted_df['Year'].apply(lambda x: 'blue' if x == '1960' else 'orange'))
plt.xlabel('Country Name')
plt.ylabel('Population')
plt.title('Comparison of Population for Top 5 Countries in 1960 and 1970')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Melt the DataFrame to reshape it into a more usable form
melted_df = df.melt(id_vars=["Country Name", "Country Code", "Indicator Name", "Indicator Code"],
                    var_name="Year", value_name="Population")

# Convert the 'Year' column to numeric values
melted_df["Year"] = pd.to_numeric(melted_df["Year"], errors="coerce")

# Find the country with the highest population
country_with_highest_population = melted_df.loc[melted_df["Population"].idxmax()]["Country Name"]
highest_population_country_data = melted_df[melted_df["Country Name"] == country_with_highest_population]

# Plot a bar graph for the highest population country
plt.figure(figsize=(10, 8))
plt.bar(highest_population_country_data["Year"], highest_population_country_data["Population"])
plt.xlabel("Year")
plt.ylabel("Population")
plt.title(f"Highest Population Country: {country_with_highest_population}")
plt.xticks(rotation=90)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# - above graph shows that population increase sligtly up from 1960 to 2022

# %%
# Calculate the correlation matrix
correlation_matrix = df.iloc[:, 4:].corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
plt.title("Correlation Heatmap")
sns.heatmap(correlation_matrix, cmap="coolwarm", annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# - Together, this code calculates the correlation matrix for the population data across different years and visualizes it using a heatmap, allowing you to see the correlation patterns between the years' population values.

# %%
# Remove rows with non-numeric identifiers (e.g., 'WLD')
numeric_columns = df.columns[4:]  # Assuming population columns start from index 4
df = df[df[numeric_columns].apply(lambda x: pd.to_numeric(x, errors='coerce')).notna().all(axis=1)]

# Select the top 5 countries based on the population in 2022
top_countries_2022 = df.nlargest(5, '2022')

# Melt the DataFrame
melted_df = top_countries_2022.melt(id_vars=['Country Name'], value_vars=df.columns[4:], var_name='Year', value_name='Population')

# Convert Population column to numeric
melted_df['Population'] = pd.to_numeric(melted_df['Population'])

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=melted_df, x='Country Name', y='Population')
plt.xlabel('Country Name')
plt.ylabel('Population')
plt.title('Population of Top 5 Countries (1960-2022)')
plt.legend(title='Year')
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# from 1960 --- 2022 only World has highest population in database

# %%
selected_year = '2020'
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x=selected_year, bins=10, kde=True)
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title(f'Population Distribution in {selected_year}')
plt.tight_layout()
plt.show()

# %%
# Melt the DataFrame
melted_df = df.melt(id_vars=['Country Name'], value_vars=df.columns[1:], var_name='Year', value_name='Population')

# Convert Population column to numeric
melted_df['Population'] = pd.to_numeric(melted_df['Population'], errors='coerce')

# Create a histogram for each year from 1960 to 2022 with different line colors
plt.figure(figsize=(24,16))
for idx, year in enumerate(range(1960, 2023)):
    year_data = melted_df[melted_df['Year'] == str(year)]
    color = sns.color_palette("Set1", n_colors=63)[idx]  # Choose a color from the palette
    sns.histplot(data=year_data, x='Population', bins=10, kde=True, label=year, color=color, alpha=0.5)

plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title('Population Distribution (1960-2022)')
plt.legend(title='Year', fontsize='medium')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Histogram shows that how year population increasing yearly

# %%
# Specify the year you're interested in (2021 in this case)
year = '2021'

# Group by 'Country Name' and select the population for the specified year
grouped_data = df.groupby('Country Name')[year].sum()

# Sort the grouped data in ascending order (low to high)
sorted_data = grouped_data.sort_values()

# Get the bottom 5 countries with the lowest population
bottom_5_countries = sorted_data.head(5)

print(bottom_5_countries)
# Out:
# Country Name
# Not classified                0.0
# Tuvalu                    11204.0
# Nauru                     12511.0
# Palau                     18024.0
# British Virgin Islands    31122.0
# Name: 2021, dtype: float64

# %%
plt.figure(figsize=(10, 6))
bottom_5_countries.plot(kind='bar')
plt.title(f'Bottom 5 Countries with Lowest Population in {year}')
plt.xlabel('Country')
plt.ylabel('Population')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Conslusion

# %%
1) above data we find that all from 1960 to 2022 population increasing fastly.
2) In dataset we see that "world" having top in every year.
3) lowest population is in "British Virgin Islands" from 1960 to 2022.
4) Together, this code calculates the correlation matrix for the population data across different years 
and visualizes it using a heatmap, allowing you to see the correlation patterns between the years' population values.
